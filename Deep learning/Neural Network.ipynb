# %% [markdown]
# # 用Python实现神经网络框架

# %% [markdown]
# $约定：x 为 1 \times n维矩阵，\omega 为n \times k维矩阵，b为1 \times k维矩阵$
# 其中x为输入数据X的某一行数据，n是输入数据X的列数，k是神经网络隐藏结点的个数

# %%
import numpy as np
from sklearn.datasets import load_boston
from sklearn.utils import shuffle, resample

# %% [markdown]
# ## 定义结点类
# 结点类初始化的时候会为如下属性赋值：
# 1. 输入结点：即与当前结点连接的上一个结点
# 2. 结点的值：当前结点的数值
# 3. 输出结点：即与当前结点连接的下一个结点
# 4. 梯度：当前结点的梯度
#
# 并定义如下方法：
# 1. 前向传播：使用原函数及上一结点value来更新当前结点的value
# 2. 反向传播：使用导数、下一结点的梯度、当前结点的梯度及上一结点的value来更新当前结点的梯度

# %%
class Node:
    def __init__(self, inbound_nodes=[]):
        self.inbound_nodes = inbound_nodes
        self.value = None
        self.outbound_nodes = []
        self.gradients = {}
        for node in inbound_nodes:
            node.outbound_nodes.append(self)

    def forward(self):
        raise NotImplementedError

    def backward(self):
        raise NotImplementedError

# %% [markdown]
# ## 定义输入结点类
# $\normalsize y = x$
#
# $\Large\frac{dy}{dx} \normalsize= 1$

# %%
class Input(Node):
    def __init__(self):
        Node.__init__(self)

    def forward(self):
        pass

    def backward(self):
        self.gradients = {self: 0}
        for n in self.outbound_nodes:
            self.gradients[self] += n.gradients[self]

# %% [markdown]
# ## 定义线性结点类
# $\normalsize y = \omega x + b$
#
# $\Large\frac{\partial y}{\partial x} \normalsize= \omega$
#
# $\Large\frac{\partial y}{\partial \omega} \normalsize= x$
#
# $\Large\frac{\partial y}{\partial b} \normalsize= 1$

# %%
class Linear(Node):
    def __init__(self, X, W, b):
        Node.__init__(self, [X, W, b])

    def forward(self):
        X = self.inbound_nodes[0].value
        W = self.inbound_nodes[1].value
        b = self.inbound_nodes[2].value
        self.value = np.dot(X, W) + b

    def backward(self):
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            self.gradients[self.inbound_nodes[0]] += np.dot(grad_cost, self.inbound_nodes[1].value.T)
            self.gradients[self.inbound_nodes[1]] += np.dot(self.inbound_nodes[0].value.T, grad_cost)
            self.gradients[self.inbound_nodes[2]] += np.sum(grad_cost, axis=0, keepdims=False)

# %% [markdown]
# ## 定义Sigmoid结点类
# $\normalsize y = \Large\frac{1}{e^x + 1}$
#
# $\Large\frac{dy}{dx} \normalsize= (1-y)y$

# %%
class Sigmoid(Node):
    def __init__(self, node):
        Node.__init__(self, [node])

    def _sigmoid(self, x):
        return 1. / (1. + np.exp(-x))

    def forward(self):
        input_value = self.inbound_nodes[0].value
        self.value = self._sigmoid(input_value)

    def backward(self):
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            sigmoid = self.value
            self.gradients[self.inbound_nodes[0]] += sigmoid * (1 - sigmoid) * grad_cost

# %% [markdown]
# ## 定义MSE结点类
# $\normalsize z = \Large \frac{1}{m}\normalsize\sum_{i=1}^{m}({y}_{i} - a_{i})^2$
# $\Large\frac{\partial z}{\partial y} \normalsize= \Large \frac{2}{m}\normalsize\sum_{i=1}^{m}({y}_{i} - a_{i})$
# $\Large\frac{\partial z}{\partial a} \normalsize=- \Large \frac{2}{m}\normalsize\sum_{i=1}^{m}({y}_{i} - a_{i})$

# %%
class MSE(Node):
    def __init__(self, y, a):
        Node.__init__(self, [y, a])

    def forward(self):
        y = self.inbound_nodes[0].value.reshape(-1, 1)
        a = self.inbound_nodes[1].value.reshape(-1, 1)

        self.m = self.inbound_nodes[0].value.shape[0]
        self.diff = y - a
        self.value = np.mean(self.diff**2)

    def backward(self):
        self.gradients[self.inbound_nodes[0]] = (2 / self.m) * self.diff
        self.gradients[self.inbound_nodes[1]] = (-2 / self.m) * self.diff

# %% [markdown]
# ## 拓扑排序
# 对结点进行排序，排序规则如下：
# 首先把所有input nodes放入列表中
# 定义一个二维字典G，把所有input nodes和其对应的outbound nodes存入字典中

# %%
def topological_sort(feed_dict):
    input_nodes = [n for n in feed_dict.keys()]

    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.outbound_nodes:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.value = feed_dict[n]

        L.append(n)
        for m in n.outbound_nodes:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            if len(G[m]['in']) == 0:
                S.add(m)
    return L

# %% [markdown]
# ## 定义正向和反向传播的方法

# %%
def forward_and_backward(graph):
    for n in graph:
        n.forward()

    for n in graph[::-1]:
        n.backward()

# %% [markdown]
# ## 定义更新梯度的方法
# 可训练结点的值 = 可训练结点的值 - 学习率 * 梯度

# %%
def sgd_update(trainables, learning_rate=1e-2):
    for t in trainables:
        partial = t.gradients[t]
        t.value -= learning_rate * partial

# %%
# Load data
data = load_boston()
X_ = data['data']
y_ = data['target']

# %%
# Normalize data
X_ = (X_ - np.mean(X_, axis=0)) / np.std(X_, axis=0)

n_features = X_.shape[1]
n_hidden = 10
W1_ = np.random.randn(n_features, n_hidden)
b1_ = np.zeros(n_hidden)
W2_ = np.random.randn(n_hidden, 1)
b2_ = np.zeros(1)

# %%
# Neural network
X, y = Input(), Input()
W1, b1 = Input(), Input()
W2, b2 = Input(), Input()

l1 = Linear(X, W1, b1)
s1 = Sigmoid(l1)
l2 = Linear(s1, W2, b2)
cost = MSE(y, l2)

feed_dict = {
    X: X_,
    y: y_,
    W1: W1_,
    b1: b1_,
    W2: W2_,
    b2: b2_
}

epochs = 1000
# Total number of examples
m = X_.shape[0]
batch_size = 11
steps_per_epoch = m // batch_size

graph = topological_sort(feed_dict)
trainables = [W1, b1, W2, b2]

print("Total number of examples = {}".format(m))
# Out:
# Total number of examples = 506

# %%
# Step 4
for i in range(epochs):
    loss = 0
    for j in range(steps_per_epoch):
        # Step 1
        # Randomly sample a batch of examples
        X_batch, y_batch = resample(X_, y_, n_samples=batch_size)

        # Reset value of X and y Inputs
        X.value = X_batch
        y.value = y_batch

        # Step 2
        forward_and_backward(graph)

        # Step 3
        sgd_update(trainables)

        loss += graph[-1].value

    print("Epoch: {}, Loss: {:.3f}".format(i+1, loss/steps_per_epoch))
# Out:
# Epoch: 1, Loss: 127.184
# Epoch: 2, Loss: 38.539
# Epoch: 3, Loss: 23.880
# Epoch: 4, Loss: 23.327
# Epoch: 5, Loss: 23.523
# Epoch: 6, Loss: 22.151
# Epoch: 7, Loss: 19.863
# Epoch: 8, Loss: 15.525
# Epoch: 9, Loss: 17.041
# Epoch: 10, Loss: 14.782
# Epoch: 11, Loss: 14.931
# Epoch: 12, Loss: 11.219
# Epoch: 13, Loss: 14.842
# Epoch: 14, Loss: 13.628
# Epoch: 15, Loss: 12.485
# Epoch: 16, Loss: 11.637
# Epoch: 17, Loss: 9.994
# Epoch: 18, Loss: 11.851
# Epoch: 19, Loss: 10.302
# Epoch: 20, Loss: 8.814
# Epoch: 21, Loss: 8.585
# Epoch: 22, Loss: 14.109
# Epoch: 23, Loss: 10.644
# Epoch: 24, Loss: 9.702
# Epoch: 25, Loss: 9.319
# Epoch: 26, Loss: 9.848
# Epoch: 27, Loss: 11.929
# Epoch: 28, Loss: 10.691
# Epoch: 29, Loss: 11.741
# Epoch: 30, Loss: 8.876
# Epoch: 31, Loss: 9.455
# Epoch: 32, Loss: 9.202
# Epoch: 33, Loss: 10.199
# Epoch: 34, Loss: 8.291
# Epoch: 35, Loss: 7.776
# Epoch: 36, Loss: 7.709
# Epoch: 37, Loss: 9.337
# Epoch: 38, Loss: 8.969
# Epoch: 39, Loss: 8.444
# Epoch: 40, Loss: 9.032
# Epoch: 41, Loss: 7.431
# Epoch: 42, Loss: 9.553
# Epoch: 43, Loss: 6.739
# Epoch: 44, Loss: 9.305
# Epoch: 45, Loss: 9.374
# Epoch: 46, Loss: 8.640
# Epoch: 47, Loss: 7.577
# Epoch: 48, Loss: 8.440
# Epoch: 49, Loss: 8.264
# Epoch: 50, Loss: 7.005
# Epoch: 51, Loss: 8.486
# Epoch: 52, Loss: 9.871
# Epoch: 53, Loss: 7.785
# Epoch: 54, Loss: 8.156
# Epoch: 55, Loss: 7.874
# Epoch: 56, Loss: 6.633
# Epoch: 57, Loss: 9.351
# Epoch: 58, Loss: 7.861
# Epoch: 59, Loss: 5.786
# Epoch: 60, Loss: 9.316
# Epoch: 61, Loss: 7.998
# Epoch: 62, Loss: 7.811
# Epoch: 63, Loss: 9.242
# Epoch: 64, Loss: 6.387
# Epoch: 65, Loss: 8.606
# Epoch: 66, Loss: 8.686
# Epoch: 67, Loss: 8.973
# Epoch: 68, Loss: 7.979
# Epoch: 69, Loss: 7.518
# Epoch: 70, Loss: 6.662
# Epoch: 71, Loss: 7.050
# Epoch: 72, Loss: 6.658
# Epoch: 73, Loss: 8.512
# Epoch: 74, Loss: 8.680
# Epoch: 75, Loss: 6.846
# Epoch: 76, Loss: 6.818
# Epoch: 77, Loss: 5.718
# Epoch: 78, Loss: 6.502
# Epoch: 79, Loss: 8.084
# Epoch: 80, Loss: 6.837
# Epoch: 81, Loss: 5.481
# Epoch: 82, Loss: 7.519
# Epoch: 83, Loss: 6.910
# Epoch: 84, Loss: 6.196
# Epoch: 85, Loss: 7.007
# Epoch: 86, Loss: 6.657
# Epoch: 87, Loss: 6.357
# Epoch: 88, Loss: 6.802
# Epoch: 89, Loss: 7.834
# Epoch: 90, Loss: 7.699
# Epoch: 91, Loss: 7.048
# Epoch: 92, Loss: 6.249
# Epoch: 93, Loss: 6.721
# Epoch: 94, Loss: 5.789
# Epoch: 95, Loss: 6.255
# Epoch: 96, Loss: 6.413
# Epoch: 97, Loss: 6.790
# Epoch: 98, Loss: 6.076
# Epoch: 99, Loss: 6.295
# Epoch: 100, Loss: 6.644
# Epoch: 101, Loss: 6.282
# Epoch: 102, Loss: 5.941
# Epoch: 103, Loss: 6.650
# Epoch: 104, Loss: 7.165
# Epoch: 105, Loss: 6.558
# Epoch: 106, Loss: 7.378
# Epoch: 107, Loss: 6.975
# Epoch: 108, Loss: 6.411
# Epoch: 109, Loss: 6.454
# Epoch: 110, Loss: 6.604
# Epoch: 111, Loss: 6.550
# Epoch: 112, Loss: 5.905
# Epoch: 113, Loss: 6.391
# Epoch: 114, Loss: 5.495
# Epoch: 115, Loss: 6.178
# Epoch: 116, Loss: 5.454
# Epoch: 117, Loss: 6.431
# Epoch: 118, Loss: 7.081
# Epoch: 119, Loss: 6.447
# Epoch: 120, Loss: 6.077
# Epoch: 121, Loss: 6.014
# Epoch: 122, Loss: 6.475
# Epoch: 123, Loss: 6.539
# Epoch: 124, Loss: 6.311
# Epoch: 125, Loss: 7.096
# Epoch: 126, Loss: 6.499
# Epoch: 127, Loss: 6.559
# Epoch: 128, Loss: 5.677
# Epoch: 129, Loss: 5.668
# Epoch: 130, Loss: 5.994
# Epoch: 131, Loss: 5.965
# Epoch: 132, Loss: 6.014
# Epoch: 133, Loss: 6.126
# Epoch: 134, Loss: 5.424
# Epoch: 135, Loss: 5.252
# Epoch: 136, Loss: 5.591
# Epoch: 137, Loss: 5.742
# Epoch: 138, Loss: 6.747
# Epoch: 139, Loss: 5.958
# Epoch: 140, Loss: 5.893
# Epoch: 141, Loss: 6.664
# Epoch: 142, Loss: 4.976
# Epoch: 143, Loss: 4.823
# Epoch: 144, Loss: 6.088
# Epoch: 145, Loss: 5.246
# Epoch: 146, Loss: 6.167
# Epoch: 147, Loss: 5.435
# Epoch: 148, Loss: 5.355
# Epoch: 149, Loss: 6.523
# Epoch: 150, Loss: 5.447
# Epoch: 151, Loss: 5.251
# Epoch: 152, Loss: 5.836
# Epoch: 153, Loss: 4.851
# Epoch: 154, Loss: 5.561
# Epoch: 155, Loss: 5.876
# Epoch: 156, Loss: 5.317
# Epoch: 157, Loss: 5.073
# Epoch: 158, Loss: 5.414
# Epoch: 159, Loss: 5.257
# Epoch: 160, Loss: 5.535
# Epoch: 161, Loss: 5.144
# Epoch: 162, Loss: 4.942
# Epoch: 163, Loss: 5.343
# Epoch: 164, Loss: 5.860
# Epoch: 165, Loss: 5.769
# Epoch: 166, Loss: 5.271
# Epoch: 167, Loss: 5.378
# Epoch: 168, Loss: 5.704
# Epoch: 169, Loss: 6.029
# Epoch: 170, Loss: 5.117
# Epoch: 171, Loss: 5.230
# Epoch: 172, Loss: 5.006
# Epoch: 173, Loss: 5.500
# Epoch: 174, Loss: 5.884
# Epoch: 175, Loss: 5.530
# Epoch: 176, Loss: 5.031
# Epoch: 177, Loss: 4.655
# Epoch: 178, Loss: 5.088
# Epoch: 179, Loss: 4.815
# Epoch: 180, Loss: 5.585
# Epoch: 181, Loss: 5.211
# Epoch: 182, Loss: 4.692
# Epoch: 183, Loss: 4.612
# Epoch: 184, Loss: 5.419
# Epoch: 185, Loss: 5.020
# Epoch: 186, Loss: 5.161
# Epoch: 187, Loss: 5.314
# Epoch: 188, Loss: 5.010
# Epoch: 189, Loss: 5.210
# Epoch: 190, Loss: 4.811
# Epoch: 191, Loss: 5.061
# Epoch: 192, Loss: 6.085
# Epoch: 193, Loss: 5.268
# Epoch: 194, Loss: 5.233
# Epoch: 195, Loss: 4.711
# Epoch: 196, Loss: 4.966
# Epoch: 197, Loss: 5.024
# Epoch: 198, Loss: 4.265
# Epoch: 199, Loss: 5.156
# Epoch: 200, Loss: 4.813
# Epoch: 201, Loss: 4.844
# Epoch: 202, Loss: 5.075
# Epoch: 203, Loss: 4.872
# Epoch: 204, Loss: 5.914
# Epoch: 205, Loss: 5.305
# Epoch: 206, Loss: 5.043
# Epoch: 207, Loss: 4.322
# Epoch: 208, Loss: 4.470
# Epoch: 209, Loss: 5.027
# Epoch: 210, Loss: 4.651
# Epoch: 211, Loss: 4.648
# Epoch: 212, Loss: 5.638
# Epoch: 213, Loss: 5.156
# Epoch: 214, Loss: 5.846
# Epoch: 215, Loss: 4.467
# Epoch: 216, Loss: 5.288
# Epoch: 217, Loss: 5.009
# Epoch: 218, Loss: 4.710
# Epoch: 219, Loss: 4.856
# Epoch: 220, Loss: 4.414
# Epoch: 221, Loss: 4.860
# Epoch: 222, Loss: 5.481
# Epoch: 223, Loss: 4.520
# Epoch: 224, Loss: 5.284
# Epoch: 225, Loss: 4.141
# Epoch: 226, Loss: 5.652
# Epoch: 227, Loss: 4.501
# Epoch: 228, Loss: 4.890
# Epoch: 229, Loss: 4.533
# Epoch: 230, Loss: 5.487
# Epoch: 231, Loss: 5.004
# Epoch: 232, Loss: 5.066
# Epoch: 233, Loss: 5.275
# Epoch: 234, Loss: 4.349
# Epoch: 235, Loss: 4.712
# Epoch: 236, Loss: 4.482
# Epoch: 237, Loss: 5.115
# Epoch: 238, Loss: 4.467
# Epoch: 239, Loss: 4.749
# Epoch: 240, Loss: 5.811
# Epoch: 241, Loss: 4.935
# Epoch: 242, Loss: 5.181
# Epoch: 243, Loss: 5.546
# Epoch: 244, Loss: 5.464
# Epoch: 245, Loss: 4.613
# Epoch: 246, Loss: 4.261
# Epoch: 247, Loss: 4.884
# Epoch: 248, Loss: 5.077
# Epoch: 249, Loss: 4.816
# Epoch: 250, Loss: 5.300
# Epoch: 251, Loss: 4.431
# Epoch: 252, Loss: 4.611
# Epoch: 253, Loss: 4.444
# Epoch: 254, Loss: 5.034
# Epoch: 255, Loss: 4.650
# Epoch: 256, Loss: 4.559
# Epoch: 257, Loss: 5.050
# Epoch: 258, Loss: 4.268
# Epoch: 259, Loss: 4.522
# Epoch: 260, Loss: 4.525
# Epoch: 261, Loss: 4.624
# Epoch: 262, Loss: 4.142
# Epoch: 263, Loss: 4.702
# Epoch: 264, Loss: 5.750
# Epoch: 265, Loss: 5.507
# Epoch: 266, Loss: 3.869
# Epoch: 267, Loss: 4.013
# Epoch: 268, Loss: 4.950
# Epoch: 269, Loss: 4.660
# Epoch: 270, Loss: 3.880
# Epoch: 271, Loss: 5.173
# Epoch: 272, Loss: 5.886
# Epoch: 273, Loss: 6.432
# Epoch: 274, Loss: 4.660
# Epoch: 275, Loss: 4.432
# Epoch: 276, Loss: 4.308
# Epoch: 277, Loss: 5.341
# Epoch: 278, Loss: 5.025
# Epoch: 279, Loss: 4.083
# Epoch: 280, Loss: 4.228
# Epoch: 281, Loss: 4.214
# Epoch: 282, Loss: 4.763
# Epoch: 283, Loss: 4.483
# Epoch: 284, Loss: 5.113
# Epoch: 285, Loss: 4.644
# Epoch: 286, Loss: 4.303
# Epoch: 287, Loss: 4.729
# Epoch: 288, Loss: 5.400
# Epoch: 289, Loss: 5.095
# Epoch: 290, Loss: 4.474
# Epoch: 291, Loss: 5.193
# Epoch: 292, Loss: 5.239
# Epoch: 293, Loss: 4.561
# Epoch: 294, Loss: 3.667
# Epoch: 295, Loss: 4.491
# Epoch: 296, Loss: 4.406
# Epoch: 297, Loss: 4.527
# Epoch: 298, Loss: 4.939
# Epoch: 299, Loss: 4.612
# Epoch: 300, Loss: 4.885
# Epoch: 301, Loss: 4.577
# Epoch: 302, Loss: 3.786
# Epoch: 303, Loss: 5.006
# Epoch: 304, Loss: 4.310
# Epoch: 305, Loss: 4.224
# Epoch: 306, Loss: 4.486
# Epoch: 307, Loss: 4.440
# Epoch: 308, Loss: 4.112
# Epoch: 309, Loss: 4.973
# Epoch: 310, Loss: 4.803
# Epoch: 311, Loss: 4.174
# Epoch: 312, Loss: 4.582
# Epoch: 313, Loss: 4.169
# Epoch: 314, Loss: 4.703
# Epoch: 315, Loss: 4.289
# Epoch: 316, Loss: 4.781
# Epoch: 317, Loss: 4.468
# Epoch: 318, Loss: 4.250
# Epoch: 319, Loss: 4.758
# Epoch: 320, Loss: 4.344
# Epoch: 321, Loss: 4.406
# Epoch: 322, Loss: 5.119
# Epoch: 323, Loss: 5.063
# Epoch: 324, Loss: 5.078
# Epoch: 325, Loss: 3.690
# Epoch: 326, Loss: 4.838
# Epoch: 327, Loss: 3.904
# Epoch: 328, Loss: 3.948
# Epoch: 329, Loss: 4.501
# Epoch: 330, Loss: 4.626
# Epoch: 331, Loss: 4.238
# Epoch: 332, Loss: 4.811
# Epoch: 333, Loss: 4.521
# Epoch: 334, Loss: 4.568
# Epoch: 335, Loss: 4.753
# Epoch: 336, Loss: 4.688
# Epoch: 337, Loss: 4.478
# Epoch: 338, Loss: 4.540
# Epoch: 339, Loss: 4.603
# Epoch: 340, Loss: 4.298
# Epoch: 341, Loss: 4.883
# Epoch: 342, Loss: 4.697
# Epoch: 343, Loss: 4.874
# Epoch: 344, Loss: 3.609
# Epoch: 345, Loss: 4.526
# Epoch: 346, Loss: 4.763
# Epoch: 347, Loss: 4.902
# Epoch: 348, Loss: 3.547
# Epoch: 349, Loss: 4.639
# Epoch: 350, Loss: 4.579
# Epoch: 351, Loss: 5.043
# Epoch: 352, Loss: 4.587
# Epoch: 353, Loss: 4.504
# Epoch: 354, Loss: 4.694
# Epoch: 355, Loss: 4.233
# Epoch: 356, Loss: 3.976
# Epoch: 357, Loss: 4.023
# Epoch: 358, Loss: 4.750
# Epoch: 359, Loss: 4.331
# Epoch: 360, Loss: 4.926
# Epoch: 361, Loss: 4.631
# Epoch: 362, Loss: 4.524
# Epoch: 363, Loss: 4.267
# Epoch: 364, Loss: 4.919
# Epoch: 365, Loss: 3.615
# Epoch: 366, Loss: 4.058
# Epoch: 367, Loss: 5.259
# Epoch: 368, Loss: 4.634
# Epoch: 369, Loss: 4.183
# Epoch: 370, Loss: 4.403
# Epoch: 371, Loss: 3.795
# Epoch: 372, Loss: 4.236
# Epoch: 373, Loss: 5.250
# Epoch: 374, Loss: 4.898
# Epoch: 375, Loss: 4.673
# Epoch: 376, Loss: 4.653
# Epoch: 377, Loss: 4.814
# Epoch: 378, Loss: 4.592
# Epoch: 379, Loss: 3.596
# Epoch: 380, Loss: 3.980
# Epoch: 381, Loss: 4.688
# Epoch: 382, Loss: 4.417
# Epoch: 383, Loss: 3.866
# Epoch: 384, Loss: 4.515
# Epoch: 385, Loss: 4.490
# Epoch: 386, Loss: 3.931
# Epoch: 387, Loss: 4.062
# Epoch: 388, Loss: 4.086
# Epoch: 389, Loss: 4.317
# Epoch: 390, Loss: 3.689
# Epoch: 391, Loss: 4.483
# Epoch: 392, Loss: 4.019
# Epoch: 393, Loss: 3.754
# Epoch: 394, Loss: 4.403
# Epoch: 395, Loss: 4.258
# Epoch: 396, Loss: 4.753
# Epoch: 397, Loss: 4.251
# Epoch: 398, Loss: 4.708
# Epoch: 399, Loss: 4.248
# Epoch: 400, Loss: 4.470
# Epoch: 401, Loss: 4.210
# Epoch: 402, Loss: 4.468
# Epoch: 403, Loss: 3.853
# Epoch: 404, Loss: 4.302
# Epoch: 405, Loss: 4.210
# Epoch: 406, Loss: 4.221
# Epoch: 407, Loss: 4.223
# Epoch: 408, Loss: 4.809
# Epoch: 409, Loss: 4.755
# Epoch: 410, Loss: 4.132
# Epoch: 411, Loss: 3.711
# Epoch: 412, Loss: 4.217
# Epoch: 413, Loss: 4.249
# Epoch: 414, Loss: 4.561
# Epoch: 415, Loss: 4.585
# Epoch: 416, Loss: 4.558
# Epoch: 417, Loss: 4.635
# Epoch: 418, Loss: 4.210
# Epoch: 419, Loss: 4.049
# Epoch: 420, Loss: 4.743
# Epoch: 421, Loss: 4.025
# Epoch: 422, Loss: 4.377
# Epoch: 423, Loss: 4.120
# Epoch: 424, Loss: 3.844
# Epoch: 425, Loss: 3.874
# Epoch: 426, Loss: 4.989
# Epoch: 427, Loss: 4.515
# Epoch: 428, Loss: 3.739
# Epoch: 429, Loss: 4.026
# Epoch: 430, Loss: 4.266
# Epoch: 431, Loss: 4.174
# Epoch: 432, Loss: 4.045
# Epoch: 433, Loss: 4.775
# Epoch: 434, Loss: 4.228
# Epoch: 435, Loss: 4.744
# Epoch: 436, Loss: 4.125
# Epoch: 437, Loss: 4.508
# Epoch: 438, Loss: 4.740
# Epoch: 439, Loss: 3.804
# Epoch: 440, Loss: 3.749
# Epoch: 441, Loss: 4.212
# Epoch: 442, Loss: 4.351
# Epoch: 443, Loss: 4.289
# Epoch: 444, Loss: 4.556
# Epoch: 445, Loss: 4.381
# Epoch: 446, Loss: 4.032
# Epoch: 447, Loss: 4.205
# Epoch: 448, Loss: 3.937
# Epoch: 449, Loss: 4.302
# Epoch: 450, Loss: 3.671
# Epoch: 451, Loss: 4.205
# Epoch: 452, Loss: 3.770
# Epoch: 453, Loss: 4.144
# Epoch: 454, Loss: 4.452
# Epoch: 455, Loss: 3.304
# Epoch: 456, Loss: 4.543
# Epoch: 457, Loss: 4.177
# Epoch: 458, Loss: 4.560
# Epoch: 459, Loss: 3.791
# Epoch: 460, Loss: 4.667
# Epoch: 461, Loss: 4.086
# Epoch: 462, Loss: 3.709
# Epoch: 463, Loss: 3.596
# Epoch: 464, Loss: 4.023
# Epoch: 465, Loss: 3.844
# Epoch: 466, Loss: 4.060
# Epoch: 467, Loss: 4.009
# Epoch: 468, Loss: 4.934
# Epoch: 469, Loss: 3.544
# Epoch: 470, Loss: 4.426
# Epoch: 471, Loss: 4.298
# Epoch: 472, Loss: 4.007
# Epoch: 473, Loss: 4.272
# Epoch: 474, Loss: 3.991
# Epoch: 475, Loss: 3.917
# Epoch: 476, Loss: 4.472
# Epoch: 477, Loss: 4.546
# Epoch: 478, Loss: 3.876
# Epoch: 479, Loss: 4.182
# Epoch: 480, Loss: 4.667
# Epoch: 481, Loss: 3.561
# Epoch: 482, Loss: 4.836
# Epoch: 483, Loss: 3.497
# Epoch: 484, Loss: 4.083
# Epoch: 485, Loss: 4.132
# Epoch: 486, Loss: 4.117
# Epoch: 487, Loss: 4.222
# Epoch: 488, Loss: 3.502
# Epoch: 489, Loss: 4.653
# Epoch: 490, Loss: 4.454
# Epoch: 491, Loss: 4.625
# Epoch: 492, Loss: 4.205
# Epoch: 493, Loss: 3.895
# Epoch: 494, Loss: 4.195
# Epoch: 495, Loss: 5.186
# Epoch: 496, Loss: 3.552
# Epoch: 497, Loss: 4.025
# Epoch: 498, Loss: 4.346
# Epoch: 499, Loss: 4.175
# Epoch: 500, Loss: 4.337
# Epoch: 501, Loss: 4.202
# Epoch: 502, Loss: 4.306
# Epoch: 503, Loss: 4.319
# Epoch: 504, Loss: 4.033
# Epoch: 505, Loss: 3.839
# Epoch: 506, Loss: 4.136
# Epoch: 507, Loss: 3.423
# Epoch: 508, Loss: 3.684
# Epoch: 509, Loss: 3.705
# Epoch: 510, Loss: 4.194
# Epoch: 511, Loss: 3.927
# Epoch: 512, Loss: 4.140
# Epoch: 513, Loss: 3.616
# Epoch: 514, Loss: 3.783
# Epoch: 515, Loss: 4.816
# Epoch: 516, Loss: 4.336
# Epoch: 517, Loss: 4.579
# Epoch: 518, Loss: 4.617
# Epoch: 519, Loss: 4.668
# Epoch: 520, Loss: 3.845
# Epoch: 521, Loss: 4.382
# Epoch: 522, Loss: 4.098
# Epoch: 523, Loss: 4.389
# Epoch: 524, Loss: 4.274
# Epoch: 525, Loss: 4.177
# Epoch: 526, Loss: 3.755
# Epoch: 527, Loss: 4.372
# Epoch: 528, Loss: 4.214
# Epoch: 529, Loss: 5.177
# Epoch: 530, Loss: 4.235
# Epoch: 531, Loss: 4.586
# Epoch: 532, Loss: 4.112
# Epoch: 533, Loss: 4.408
# Epoch: 534, Loss: 4.626
# Epoch: 535, Loss: 4.038
# Epoch: 536, Loss: 3.906
# Epoch: 537, Loss: 4.211
# Epoch: 538, Loss: 3.982
# Epoch: 539, Loss: 4.188
# Epoch: 540, Loss: 4.126
# Epoch: 541, Loss: 4.419
# Epoch: 542, Loss: 4.028
# Epoch: 543, Loss: 4.425
# Epoch: 544, Loss: 4.270
# Epoch: 545, Loss: 4.614
# Epoch: 546, Loss: 4.309
# Epoch: 547, Loss: 3.985
# Epoch: 548, Loss: 3.963
# Epoch: 549, Loss: 3.769
# Epoch: 550, Loss: 4.168
# Epoch: 551, Loss: 4.214
# Epoch: 552, Loss: 3.951
# Epoch: 553, Loss: 4.147
# Epoch: 554, Loss: 3.938
# Epoch: 555, Loss: 4.112
# Epoch: 556, Loss: 3.949
# Epoch: 557, Loss: 4.280
# Epoch: 558, Loss: 4.317
# Epoch: 559, Loss: 4.349
# Epoch: 560, Loss: 4.536
# Epoch: 561, Loss: 3.595
# Epoch: 562, Loss: 4.015
# Epoch: 563, Loss: 3.809
# Epoch: 564, Loss: 4.561
# Epoch: 565, Loss: 4.338
# Epoch: 566, Loss: 3.908
# Epoch: 567, Loss: 3.732
# Epoch: 568, Loss: 3.906
# Epoch: 569, Loss: 4.018
# Epoch: 570, Loss: 3.675
# Epoch: 571, Loss: 3.925
# Epoch: 572, Loss: 4.135
# Epoch: 573, Loss: 4.222
# Epoch: 574, Loss: 4.461
# Epoch: 575, Loss: 4.405
# Epoch: 576, Loss: 4.530
# Epoch: 577, Loss: 4.346
# Epoch: 578, Loss: 3.671
# Epoch: 579, Loss: 4.214
# Epoch: 580, Loss: 3.839
# Epoch: 581, Loss: 4.270
# Epoch: 582, Loss: 4.224
# Epoch: 583, Loss: 4.098
# Epoch: 584, Loss: 3.582
# Epoch: 585, Loss: 3.990
# Epoch: 586, Loss: 3.843
# Epoch: 587, Loss: 4.100
# Epoch: 588, Loss: 4.318
# Epoch: 589, Loss: 4.047
# Epoch: 590, Loss: 4.736
# Epoch: 591, Loss: 4.175
# Epoch: 592, Loss: 3.559
# Epoch: 593, Loss: 4.473
# Epoch: 594, Loss: 4.318
# Epoch: 595, Loss: 3.875
# Epoch: 596, Loss: 4.261
# Epoch: 597, Loss: 4.599
# Epoch: 598, Loss: 3.934
# Epoch: 599, Loss: 4.397
# Epoch: 600, Loss: 3.952
# Epoch: 601, Loss: 4.236
# Epoch: 602, Loss: 3.816
# Epoch: 603, Loss: 4.127
# Epoch: 604, Loss: 3.949
# Epoch: 605, Loss: 4.014
# Epoch: 606, Loss: 3.891
# Epoch: 607, Loss: 3.954
# Epoch: 608, Loss: 4.491
# Epoch: 609, Loss: 3.707
# Epoch: 610, Loss: 3.880
# Epoch: 611, Loss: 3.678
# Epoch: 612, Loss: 4.197
# Epoch: 613, Loss: 4.355
# Epoch: 614, Loss: 3.929
# Epoch: 615, Loss: 3.852
# Epoch: 616, Loss: 4.640
# Epoch: 617, Loss: 3.735
# Epoch: 618, Loss: 4.415
# Epoch: 619, Loss: 3.379
# Epoch: 620, Loss: 3.968
# Epoch: 621, Loss: 3.808
# Epoch: 622, Loss: 4.009
# Epoch: 623, Loss: 4.254
# Epoch: 624, Loss: 3.564
# Epoch: 625, Loss: 3.652
# Epoch: 626, Loss: 3.652
# Epoch: 627, Loss: 4.126
# Epoch: 628, Loss: 4.494
# Epoch: 629, Loss: 3.745
# Epoch: 630, Loss: 4.094
# Epoch: 631, Loss: 3.077
# Epoch: 632, Loss: 4.220
# Epoch: 633, Loss: 4.196
# Epoch: 634, Loss: 4.591
# Epoch: 635, Loss: 3.467
# Epoch: 636, Loss: 4.039
# Epoch: 637, Loss: 3.897
# Epoch: 638, Loss: 3.858
# Epoch: 639, Loss: 4.566
# Epoch: 640, Loss: 3.647
# Epoch: 641, Loss: 3.863
# Epoch: 642, Loss: 3.757
# Epoch: 643, Loss: 4.268
# Epoch: 644, Loss: 3.286
# Epoch: 645, Loss: 4.407
# Epoch: 646, Loss: 4.129
# Epoch: 647, Loss: 4.143
# Epoch: 648, Loss: 3.188
# Epoch: 649, Loss: 4.320
# Epoch: 650, Loss: 3.858
# Epoch: 651, Loss: 3.765
# Epoch: 652, Loss: 3.920
# Epoch: 653, Loss: 3.897
# Epoch: 654, Loss: 4.191
# Epoch: 655, Loss: 3.935
# Epoch: 656, Loss: 3.645
# Epoch: 657, Loss: 3.591
# Epoch: 658, Loss: 3.555
# Epoch: 659, Loss: 3.326
# Epoch: 660, Loss: 3.731
# Epoch: 661, Loss: 4.021
# Epoch: 662, Loss: 4.161
# Epoch: 663, Loss: 3.866
# Epoch: 664, Loss: 4.812
# Epoch: 665, Loss: 4.374
# Epoch: 666, Loss: 4.027
# Epoch: 667, Loss: 3.920
# Epoch: 668, Loss: 3.990
# Epoch: 669, Loss: 4.561
# Epoch: 670, Loss: 4.872
# Epoch: 671, Loss: 3.959
# Epoch: 672, Loss: 4.414
# Epoch: 673, Loss: 3.639
# Epoch: 674, Loss: 3.599
# Epoch: 675, Loss: 3.952
# Epoch: 676, Loss: 3.778
# Epoch: 677, Loss: 3.347
# Epoch: 678, Loss: 4.055
# Epoch: 679, Loss: 3.683
# Epoch: 680, Loss: 3.838
# Epoch: 681, Loss: 4.526
# Epoch: 682, Loss: 3.801
# Epoch: 683, Loss: 4.235
# Epoch: 684, Loss: 4.283
# Epoch: 685, Loss: 3.513
# Epoch: 686, Loss: 4.157
# Epoch: 687, Loss: 4.166
# Epoch: 688, Loss: 3.587
# Epoch: 689, Loss: 4.177
# Epoch: 690, Loss: 4.504
# Epoch: 691, Loss: 3.728
# Epoch: 692, Loss: 4.345
# Epoch: 693, Loss: 3.878
# Epoch: 694, Loss: 4.518
# Epoch: 695, Loss: 4.216
# Epoch: 696, Loss: 3.949
# Epoch: 697, Loss: 4.020
# Epoch: 698, Loss: 4.130
# Epoch: 699, Loss: 4.198
# Epoch: 700, Loss: 3.763
# Epoch: 701, Loss: 4.011
# Epoch: 702, Loss: 3.894
# Epoch: 703, Loss: 3.782
# Epoch: 704, Loss: 3.825
# Epoch: 705, Loss: 3.166
# Epoch: 706, Loss: 3.890
# Epoch: 707, Loss: 3.788
# Epoch: 708, Loss: 3.350
# Epoch: 709, Loss: 3.873
# Epoch: 710, Loss: 4.200
# Epoch: 711, Loss: 3.978
# Epoch: 712, Loss: 4.149
# Epoch: 713, Loss: 3.660
# Epoch: 714, Loss: 3.902
# Epoch: 715, Loss: 3.852
# Epoch: 716, Loss: 3.668
# Epoch: 717, Loss: 3.965
# Epoch: 718, Loss: 3.568
# Epoch: 719, Loss: 3.937
# Epoch: 720, Loss: 3.412
# Epoch: 721, Loss: 3.457
# Epoch: 722, Loss: 3.617
# Epoch: 723, Loss: 3.959
# Epoch: 724, Loss: 4.052
# Epoch: 725, Loss: 3.825
# Epoch: 726, Loss: 4.071
# Epoch: 727, Loss: 3.765
# Epoch: 728, Loss: 4.163
# Epoch: 729, Loss: 3.722
# Epoch: 730, Loss: 3.686
# Epoch: 731, Loss: 3.145
# Epoch: 732, Loss: 3.379
# Epoch: 733, Loss: 4.417
# Epoch: 734, Loss: 4.057
# Epoch: 735, Loss: 3.623
# Epoch: 736, Loss: 3.896
# Epoch: 737, Loss: 3.584
# Epoch: 738, Loss: 4.349
# Epoch: 739, Loss: 4.544
# Epoch: 740, Loss: 4.178
# Epoch: 741, Loss: 3.761
# Epoch: 742, Loss: 4.083
# Epoch: 743, Loss: 4.066
# Epoch: 744, Loss: 4.211
# Epoch: 745, Loss: 3.919
# Epoch: 746, Loss: 4.097
# Epoch: 747, Loss: 3.737
# Epoch: 748, Loss: 3.989
# Epoch: 749, Loss: 4.661
# Epoch: 750, Loss: 3.780
# Epoch: 751, Loss: 4.062
# Epoch: 752, Loss: 4.239
# Epoch: 753, Loss: 3.660
# Epoch: 754, Loss: 3.966
# Epoch: 755, Loss: 3.755
# Epoch: 756, Loss: 4.631
# Epoch: 757, Loss: 3.955
# Epoch: 758, Loss: 4.301
# Epoch: 759, Loss: 3.943
# Epoch: 760, Loss: 3.743
# Epoch: 761, Loss: 3.552
# Epoch: 762, Loss: 3.768
# Epoch: 763, Loss: 3.814
# Epoch: 764, Loss: 3.435
# Epoch: 765, Loss: 3.620
# Epoch: 766, Loss: 3.359
# Epoch: 767, Loss: 3.365
# Epoch: 768, Loss: 3.651
# Epoch: 769, Loss: 3.959
# Epoch: 770, Loss: 3.343
# Epoch: 771, Loss: 3.727
# Epoch: 772, Loss: 4.039
# Epoch: 773, Loss: 4.327
# Epoch: 774, Loss: 3.717
# Epoch: 775, Loss: 4.058
# Epoch: 776, Loss: 3.711
# Epoch: 777, Loss: 3.514
# Epoch: 778, Loss: 3.756
# Epoch: 779, Loss: 3.660
# Epoch: 780, Loss: 4.333
# Epoch: 781, Loss: 4.539
# Epoch: 782, Loss: 3.989
# Epoch: 783, Loss: 3.500
# Epoch: 784, Loss: 3.815
# Epoch: 785, Loss: 3.226
# Epoch: 786, Loss: 4.025
# Epoch: 787, Loss: 3.944
# Epoch: 788, Loss: 3.467
# Epoch: 789, Loss: 3.761
# Epoch: 790, Loss: 3.935
# Epoch: 791, Loss: 3.504
# Epoch: 792, Loss: 3.742
# Epoch: 793, Loss: 4.010
# Epoch: 794, Loss: 4.300
# Epoch: 795, Loss: 3.367
# Epoch: 796, Loss: 3.319
# Epoch: 797, Loss: 4.130
# Epoch: 798, Loss: 3.832
# Epoch: 799, Loss: 3.863
# Epoch: 800, Loss: 3.618
# Epoch: 801, Loss: 4.010
# Epoch: 802, Loss: 3.531
# Epoch: 803, Loss: 3.667
# Epoch: 804, Loss: 4.203
# Epoch: 805, Loss: 3.681
# Epoch: 806, Loss: 3.547
# Epoch: 807, Loss: 4.068
# Epoch: 808, Loss: 3.905
# Epoch: 809, Loss: 3.605
# Epoch: 810, Loss: 3.713
# Epoch: 811, Loss: 3.440
# Epoch: 812, Loss: 4.184
# Epoch: 813, Loss: 4.493
# Epoch: 814, Loss: 3.611
# Epoch: 815, Loss: 4.019
# Epoch: 816, Loss: 3.808
# Epoch: 817, Loss: 4.604
# Epoch: 818, Loss: 3.464
# Epoch: 819, Loss: 4.261
# Epoch: 820, Loss: 4.121
# Epoch: 821, Loss: 4.258
# Epoch: 822, Loss: 3.697
# Epoch: 823, Loss: 3.968
# Epoch: 824, Loss: 4.110
# Epoch: 825, Loss: 4.073
# Epoch: 826, Loss: 3.858
# Epoch: 827, Loss: 3.872
# Epoch: 828, Loss: 3.667
# Epoch: 829, Loss: 4.539
# Epoch: 830, Loss: 3.813
# Epoch: 831, Loss: 3.808
# Epoch: 832, Loss: 3.975
# Epoch: 833, Loss: 4.413
# Epoch: 834, Loss: 4.249
# Epoch: 835, Loss: 4.187
# Epoch: 836, Loss: 3.786
# Epoch: 837, Loss: 4.287
# Epoch: 838, Loss: 4.788
# Epoch: 839, Loss: 3.256
# Epoch: 840, Loss: 3.924
# Epoch: 841, Loss: 4.194
# Epoch: 842, Loss: 3.837
# Epoch: 843, Loss: 3.587
# Epoch: 844, Loss: 3.739
# Epoch: 845, Loss: 3.815
# Epoch: 846, Loss: 4.194
# Epoch: 847, Loss: 3.892
# Epoch: 848, Loss: 4.312
# Epoch: 849, Loss: 4.578
# Epoch: 850, Loss: 3.350
# Epoch: 851, Loss: 4.330
# Epoch: 852, Loss: 3.962
# Epoch: 853, Loss: 4.110
# Epoch: 854, Loss: 3.818
# Epoch: 855, Loss: 4.111
# Epoch: 856, Loss: 3.871
# Epoch: 857, Loss: 4.018
# Epoch: 858, Loss: 4.048
# Epoch: 859, Loss: 4.023
# Epoch: 860, Loss: 3.674
# Epoch: 861, Loss: 3.769
# Epoch: 862, Loss: 3.627
# Epoch: 863, Loss: 3.820
# Epoch: 864, Loss: 3.805
# Epoch: 865, Loss: 3.253
# Epoch: 866, Loss: 3.841
# Epoch: 867, Loss: 4.285
# Epoch: 868, Loss: 3.808
# Epoch: 869, Loss: 3.741
# Epoch: 870, Loss: 4.228
# Epoch: 871, Loss: 3.799
# Epoch: 872, Loss: 3.438
# Epoch: 873, Loss: 3.536
# Epoch: 874, Loss: 3.318
# Epoch: 875, Loss: 4.019
# Epoch: 876, Loss: 3.971
# Epoch: 877, Loss: 3.485
# Epoch: 878, Loss: 3.724
# Epoch: 879, Loss: 3.889
# Epoch: 880, Loss: 3.706
# Epoch: 881, Loss: 3.852
# Epoch: 882, Loss: 4.472
# Epoch: 883, Loss: 3.621
# Epoch: 884, Loss: 4.084
# Epoch: 885, Loss: 3.620
# Epoch: 886, Loss: 3.188
# Epoch: 887, Loss: 3.570
# Epoch: 888, Loss: 3.538
# Epoch: 889, Loss: 3.276
# Epoch: 890, Loss: 3.694
# Epoch: 891, Loss: 3.626
# Epoch: 892, Loss: 4.125
# Epoch: 893, Loss: 3.720
# Epoch: 894, Loss: 3.520
# Epoch: 895, Loss: 3.783
# Epoch: 896, Loss: 4.164
# Epoch: 897, Loss: 4.114
# Epoch: 898, Loss: 3.456
# Epoch: 899, Loss: 3.806
# Epoch: 900, Loss: 3.445
# Epoch: 901, Loss: 3.841
# Epoch: 902, Loss: 3.830
# Epoch: 903, Loss: 3.128
# Epoch: 904, Loss: 3.560
# Epoch: 905, Loss: 4.028
# Epoch: 906, Loss: 3.595
# Epoch: 907, Loss: 3.932
# Epoch: 908, Loss: 3.769
# Epoch: 909, Loss: 3.518
# Epoch: 910, Loss: 3.559
# Epoch: 911, Loss: 3.652
# Epoch: 912, Loss: 3.278
# Epoch: 913, Loss: 3.716
# Epoch: 914, Loss: 3.744
# Epoch: 915, Loss: 3.225
# Epoch: 916, Loss: 4.656
# Epoch: 917, Loss: 4.200
# Epoch: 918, Loss: 3.522
# Epoch: 919, Loss: 3.783
# Epoch: 920, Loss: 3.640
# Epoch: 921, Loss: 4.396
# Epoch: 922, Loss: 3.952
# Epoch: 923, Loss: 3.378
# Epoch: 924, Loss: 3.769
# Epoch: 925, Loss: 3.998
# Epoch: 926, Loss: 3.980
# Epoch: 927, Loss: 3.722
# Epoch: 928, Loss: 4.508
# Epoch: 929, Loss: 3.688
# Epoch: 930, Loss: 3.934
# Epoch: 931, Loss: 3.877
# Epoch: 932, Loss: 3.795
# Epoch: 933, Loss: 3.468
# Epoch: 934, Loss: 3.502
# Epoch: 935, Loss: 3.678
# Epoch: 936, Loss: 3.623
# Epoch: 937, Loss: 3.320
# Epoch: 938, Loss: 3.260
# Epoch: 939, Loss: 3.720
# Epoch: 940, Loss: 3.896
# Epoch: 941, Loss: 3.658
# Epoch: 942, Loss: 3.768
# Epoch: 943, Loss: 3.586
# Epoch: 944, Loss: 4.007
# Epoch: 945, Loss: 4.117
# Epoch: 946, Loss: 4.342
# Epoch: 947, Loss: 3.357
# Epoch: 948, Loss: 3.513
# Epoch: 949, Loss: 3.610
# Epoch: 950, Loss: 3.528
# Epoch: 951, Loss: 3.771
# Epoch: 952, Loss: 3.704
# Epoch: 953, Loss: 3.903
# Epoch: 954, Loss: 3.658
# Epoch: 955, Loss: 3.775
# Epoch: 956, Loss: 3.489
# Epoch: 957, Loss: 4.538
# Epoch: 958, Loss: 3.752
# Epoch: 959, Loss: 4.048
# Epoch: 960, Loss: 3.911
# Epoch: 961, Loss: 3.931
# Epoch: 962, Loss: 3.548
# Epoch: 963, Loss: 3.909
# Epoch: 964, Loss: 4.198
# Epoch: 965, Loss: 3.642
# Epoch: 966, Loss: 3.719
# Epoch: 967, Loss: 3.567
# Epoch: 968, Loss: 3.559
# Epoch: 969, Loss: 3.118
# Epoch: 970, Loss: 3.314
# Epoch: 971, Loss: 3.196
# Epoch: 972, Loss: 4.075
# Epoch: 973, Loss: 4.012
# Epoch: 974, Loss: 3.945
# Epoch: 975, Loss: 3.724
# Epoch: 976, Loss: 3.509
# Epoch: 977, Loss: 3.736
# Epoch: 978, Loss: 3.748
# Epoch: 979, Loss: 3.597
# Epoch: 980, Loss: 3.682
# Epoch: 981, Loss: 3.984
# Epoch: 982, Loss: 3.737
# Epoch: 983, Loss: 3.393
# Epoch: 984, Loss: 3.261
# Epoch: 985, Loss: 3.585
# Epoch: 986, Loss: 4.046
# Epoch: 987, Loss: 4.066
# Epoch: 988, Loss: 3.244
# Epoch: 989, Loss: 4.272
# Epoch: 990, Loss: 4.423
# Epoch: 991, Loss: 4.127
# Epoch: 992, Loss: 4.124
# Epoch: 993, Loss: 4.128
# Epoch: 994, Loss: 3.515
# Epoch: 995, Loss: 3.356
# Epoch: 996, Loss: 4.629
# Epoch: 997, Loss: 4.004
# Epoch: 998, Loss: 3.559
# Epoch: 999, Loss: 4.047
# Epoch: 1000, Loss: 3.862
